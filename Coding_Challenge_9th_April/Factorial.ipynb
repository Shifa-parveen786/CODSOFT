# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/CODSOFT/blob/main/Coding_Challenge_9th_April/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A math tool calculates factorial
#-----------------------------------------------------
# Function to calculate factorial of a number
def factorial(n):
    # Initialize result as 1
    fact = 1

    # Loop from 1 to n
    for i in range(1, n + 1):
        fact *= i   # Multiply each number

    # Return factorial value
    return fact


# Taking input from user
num = int(input("Enter number: "))

# Calling the function and storing result
result = factorial(num)

# Printing the result
print(result)
# Out:
# Enter number: 5
# 120
